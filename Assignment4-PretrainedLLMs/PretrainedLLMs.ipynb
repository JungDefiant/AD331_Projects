# %%
### Generative AI with Pre-trained LLMs
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, set_seed

set_seed(42)

device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained("distilbert/distilgpt2")
model = AutoModelForCausalLM.from_pretrained("distilbert/distilgpt2", pad_token_id=tokenizer.eos_token_id).to(device)

# %%
model_inputs = tokenizer('My favorite ice cream flavor is ', return_tensors='pt').to(device)
outputs = model.generate(
    **model_inputs, 
    max_new_tokens=50,
    do_sample=True,
    top_k=50,
    )
tokenizer.batch_decode(outputs, skip_special_tokens=True)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ['My favorite ice cream flavor is iced cream with red wine, cream cheese and cream cheese. I also like ice cream with pumpkin, sweet butter and sugar. You can find it at my blog, in-store recipes section, or at my blog.']

# %%
outputs = model.generate(
    **model_inputs, 
    max_new_tokens=50,
    do_sample=True,
    top_p=0.9,
    top_k=50,
    temperature=0.6
    )
tokenizer.batch_decode(outputs, skip_special_tokens=True)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ['My favorite ice cream flavor is iced cream. I like the texture of the cream. I like the texture of the cream. I like the texture of the cream. I like the texture of the cream. I like the texture of the cream. I like the texture of the cream']

# %%
outputs = model.generate(
    **model_inputs, 
    max_new_tokens=50,
    do_sample=True,
    top_p=0.9,
    top_k=50,
    temperature=0.2
    )
tokenizer.batch_decode(outputs, skip_special_tokens=True)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ['My favorite ice cream flavor is iced cream. I love it. I love it. I love it. I love it. I love it. I love it. I love it. I love it. I love it. I love it. I love it. I love it']

# %%
outputs = model.generate(
    **model_inputs, 
    max_new_tokens=50,
    do_sample=True,
    top_p=0.6,
    top_k=50,
    temperature=0.6
    )
tokenizer.batch_decode(outputs, skip_special_tokens=True)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ["My favorite ice cream flavor is iced with a hint of vanilla. I've been craving this for a while now and I've been craving this for a while now and I've been craving this for a while now and I've been craving this for a while now and I've been"]

# %%
outputs = model.generate(
    **model_inputs, 
    max_new_tokens=150,
    do_sample=True,
    top_p=0.9,
    top_k=50,
    temperature=0.6
    )
tokenizer.batch_decode(outputs, skip_special_tokens=True)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ['My favorite ice cream flavor is iced with the melted butter. I like to add a bit of extra flavor to the ice cream. I love the flavors that I use to make my ice cream. The ice cream is very smooth and I like the flavors that I use to make my ice cream. I love the flavors that I use to make my ice cream. The ice cream is very smooth and I like the flavors that I use to make my ice cream. The ice cream is very smooth and I like the flavors that I use to make my ice cream. The ice cream is very smooth and I like the flavors that I use to make my ice cream. The ice cream is very smooth and I like the flavors that I use to make my ice cream. The ice cream is']

# %%
# Best Test Case
outputs = model.generate(
    **model_inputs, 
    max_new_tokens=150,
    do_sample=True,
    top_p=0.9,
    top_k=50,
    temperature=0.3
    )
tokenizer.batch_decode(outputs, skip_special_tokens=True)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ['My favorite ice cream flavor is iced cream with a creamy vanilla extract.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n']
