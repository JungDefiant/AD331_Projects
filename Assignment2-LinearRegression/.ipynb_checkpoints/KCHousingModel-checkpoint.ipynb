# %%
### Linear Regression, Data Cleaning, and Feature Engineering

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sklearn as sci
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
## Loading Data
data_url = "./kc_house_data.csv"
kc_data = pd.read_csv(data_url)

print(kc_data.columns)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
## Data Cleaning
kc_data = kc_data.dropna(axis=0)

print(kc_data)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 1      6414100192   12/9/2014   538000.0         3       2.25         2570
# 3      2487200875   12/9/2014   604000.0         4       3.00         1960
# 4      1954400510   2/18/2015   510000.0         3       2.00         1680
# 5      7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6      1321400060   6/27/2014   257500.0         3       2.25         1715
# ...           ...         ...        ...       ...        ...          ...
# 21591  2997800021   2/19/2015   475000.0         3       2.50         1310
# 21592   263000018   5/21/2014   360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015   400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014   402101.0         2       0.75         1020
# 21596  1523300157  10/15/2014   325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1          7242     2.0         0.0   0.0  ...      7        2170
# 3          5000     1.0         0.0   0.0  ...      7        1050
# 4          8080     1.0         0.0   0.0  ...      8        1680
# 5        101930     1.0         0.0   0.0  ...     11        3890
# 6          6819     2.0         0.0   0.0  ...      7        1715
# ...         ...     ...         ...   ...  ...    ...         ...
# 21591      1294     2.0         0.0   0.0  ...      8        1180
# 21592      1131     3.0         0.0   0.0  ...      8        1530
# 21593      5813     2.0         0.0   0.0  ...      8        2310
# 21594      1350     2.0         0.0   0.0  ...      7        1020
# 21596      1076     2.0         0.0   0.0  ...      7        1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 1              400.0     1951        1991.0    98125  47.7210 -122.319
# 3              910.0     1965           0.0    98136  47.5208 -122.393
# 4                0.0     1987           0.0    98074  47.6168 -122.045
# 5             1530.0     2001           0.0    98053  47.6561 -122.005
# 6                  ?     1995           0.0    98003  47.3097 -122.327
# ...              ...      ...           ...      ...      ...      ...
# 21591          130.0     2008           0.0    98116  47.5773 -122.409
# 21592            0.0     2009           0.0    98103  47.6993 -122.346
# 21593            0.0     2014           0.0    98146  47.5107 -122.362
# 21594            0.0     2009           0.0    98144  47.5944 -122.299
# 21596            0.0     2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 1               1690        7639
# 3               1360        5000
# 4               1800        7503
# 5               4760      101930
# 6               2238        6819
# ...              ...         ...
# 21591           1330        1265
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21596           1020        1357
#
# [15762 rows x 21 columns]

# %%
## Feature Engineering
y = kc_data.price

# Create new numerical feature - age of house based on year built
current_year = 2025
kc_data['age'] = kc_data.apply(lambda row: current_year - row['yr_built'], axis=1)

kc_features = ['age', 'waterfront', 'bedrooms', 'bathrooms', 'sqft_living']

x = kc_data[kc_features]
x.describe()
# Out:
#                 age    waterfront      bedrooms     bathrooms   sqft_living
# count  15762.000000  15762.000000  15762.000000  15762.000000  15762.000000
# mean      53.888783      0.007613      3.378949      2.120797   2084.512372
# std       29.336823      0.086924      0.935301      0.766772    918.617686
# min       10.000000      0.000000      1.000000      0.500000    370.000000
# 25%       28.000000      0.000000      3.000000      1.750000   1430.000000
# 50%       50.000000      0.000000      3.000000      2.250000   1920.000000
# 75%       73.000000      0.000000      4.000000      2.500000   2550.000000
# max      125.000000      1.000000     33.000000      8.000000  13540.000000

# %%
x.head()
# Out:
#    age  waterfront  bedrooms  bathrooms  sqft_living
# 1   74         0.0         3       2.25         2570
# 3   60         0.0         4       3.00         1960
# 4   38         0.0         3       2.00         1680
# 5   24         0.0         4       4.50         5420
# 6   30         0.0         3       2.25         1715

# %%
## Model Implementation

# Split the datasets into training and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)

# %%
x_test.head()
# Out:
#        age  waterfront  bedrooms  bathrooms  sqft_living
# 17979   28         0.0         3        2.5         1860
# 5370    62         0.0         3        1.5         1360
# 17573   75         0.0         2        1.0         1760
# 13615   93         0.0         2        1.0          930
# 12982   36         0.0         3        2.5         1460

# %%
x_train.head()
# Out:
#        age  waterfront  bedrooms  bathrooms  sqft_living
# 16362   46         0.0         4       2.25         2600
# 17903   18         0.0         3       2.25         1350
# 14334   71         0.0         4       1.00         1730
# 8329    61         0.0         3       1.75         1220
# 15768   77         0.0         3       1.00         1590

# %%
y_test.head()
# Out:
# 17979    410000.0
# 5370     244000.0
# 17573    428950.0
# 13615    105500.0
# 12982    245000.0
# Name: price, dtype: float64

# %%
y_train.head()
# Out:
# 16362    817000.0
# 17903    397500.0
# 14334    319000.0
# 8329     500000.0
# 15768    579000.0
# Name: price, dtype: float64

# %%
# Defining Linear Regression model
kc_model = LinearRegression()

# Fit model
kc_model.fit(x, y)
# Out:
# LinearRegression()

# %%
# Test predictions with first 5 houses of testing set
kc_model.predict(x_test.head())
# Out:
# array([447574.12421439, 320244.62551848, 499123.84563665, 308913.32355477,
#        353896.67069962])

# %%
## Evaluating Model Accuracy
from sklearn.metrics import mean_absolute_error

predicted_home_prices_test = kc_model.predict(x_test)
mean_absolute_error(y_test, predicted_home_prices_test)
# Out:
# 158117.7595268458

# %%
from sklearn.metrics import r2_score
r2_score(y_test, predicted_home_prices_test)
# Out:
# 0.6151075639856439

# %%
plt.plot(x_test['age'], y_test, 'o')
m, b = np.polyfit(x_test['age'], predicted_home_prices_test, 1)
plt.plot(x_test['age'], m*x_test['age']+b)
plt.title("King County Housing: Pricing Predictions")
plt.xlabel("Age")
plt.ylabel("Price (in $10,000)")
plt.show()
